# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df.shape
# Out:
# (1000, 3)

# %%
plt.hist(df['placement_exam_marks'], bins=30, density=True, alpha=0.5, color='blue')
plt.title('Histogram of Data')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(x=df['placement_exam_marks'])
plt.title('Box Plot')
plt.grid(True)
plt.show()

# %%
# Finding the IQR
percentile25 = df['placement_exam_marks'].quantile(0.25) # Q1
percentile75 = df['placement_exam_marks'].quantile(0.75) # Q3

# %%
percentile75
# Out:
# 44.0

# %%
iqr = percentile75 - percentile25
# IQR = Q3    -        Q1
print(iqr)
# Out:
# 27.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 84.5
# Lower limit -23.5

# %% [markdown]
# Finding Outliers

# %%
df[df['placement_exam_marks'] > upper_limit]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-89f9156e50c8> in <cell line: 1>()
# ----> 1 df[df['placement_exam_marks'] > upper_limit]
#       2 len(df[df['placement_exam_marks'] > upper_limit])
#
# NameError: name 'df' is not defined

# %%
df[df['placement_exam_marks'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [cgpa, placement_exam_marks, placed]
# Index: []

# %% [markdown]
# Trimming

# %%
new_df = df[df['placement_exam_marks'] < upper_limit]
new_df.shape
# Out:
# (985, 3)

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(x=new_df['placement_exam_marks'])
plt.title('Box Plot')
plt.grid(True)
plt.show()
